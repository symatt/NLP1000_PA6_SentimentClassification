# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# %%
def compute_accuracy(predictions, actual):
    p = predictions
    a = actual
    if type(p) is not np.ndarray:
        p = p.to_numpy()
    if type(a) is not np.ndarray:
        a = a.to_numpy()
    correct = 0
    for i in range(len(a)):
        if p[i] == a[i]:
            correct += 1
    return correct / len(a) * 100

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
# load data
sentiments = pd.read_csv("train.csv")
sentiments.dropna(inplace=True)

# label_enc = preprocessing.LabelEncoder()
# label_enc.fit(sentiments['IsPositive'])

# mapping = dict(zip(label_enc.classes_, label_enc.transform(label_enc.classes_)))
# print("Mapping:", mapping)

# sentiments["IsPositive"] = label_enc.transform(sentiments["IsPositive"])

X = sentiments["Text"]
y = sentiments["IsPositive"]
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
# tagalog - https://github.com/explosion/spaCy/discussions/6122
# english - https://gist.githubusercontent.com/ZohebAbai/513218c3468130eacff6481f424e4e64/raw/b70776f341a148293ff277afa0d0302c8c38f7e2/gist_stopwords.txt
# punctuations - ourselves
gist_file = open("gist_stopwords.txt", "r")
try:
    content = gist_file.read()
    stopwords = content.split(",")
finally:
    gist_file.close()
tagalog = ['ba',
 'eh',
 'kasi',
 'lang',
 'mo',
 'naman',
 'opo',
 'po',
 'si',
 'talaga',
 'yung',
]
punctuations = ['!', '.', ',', '\"', '\'', ';', ':', '?', '*', '%', '@', '&', '$', '^', '(', ')', '_', '-', '+', '=']
stopwords += tagalog
stopwords += punctuations

# %%
count_vect = CountVectorizer(stop_words=stopwords, token_pattern=r'[^\s]+')
count_vect.fit(X_train)
# Out:
# CountVectorizer(stop_words=['0o', '0s', '3a', '3b', '3d', '6b', '6o', 'a', 'a1',
#                             'a2', 'a3', 'a4', 'ab', 'able', 'about', 'above',
#                             'abst', 'ac', 'accordance', 'according',
#                             'accordingly', 'across', 'act', 'actually', 'ad',
#                             'added', 'adj', 'ae', 'af', 'affected', ...],
#                 token_pattern='[^\\s]+')

# %%
X_train_count_sparse_matrix = count_vect.transform(X_train)
X_validation_count_sparse_matrix = count_vect.transform(X_validation)

# %%
from sklearn.model_selection import ParameterGrid

# %%
sentiment_nb = MultinomialNB()
sentiment_nb.get_params()
hyperparameters = [{
    'alpha': [0.05,0.1,0.5,1,3,5,10,15],
    'fit_prior': [True, False]
}]

# %%
best_score = 0
for g in ParameterGrid(hyperparameters):
    print(g)
    
    sentiment_nb.set_params(**g)
    
    sentiment_nb.fit(X_train_count_sparse_matrix, y_train)
    predictions = sentiment_nb.predict(X_train_count_sparse_matrix)
    train_acc = compute_accuracy(predictions, y_train)
    
    predictions = sentiment_nb.predict(X_validation_count_sparse_matrix)
    val_acc = compute_accuracy(predictions, y_validation)
    
    print(f"Train acc: {train_acc}% \t Val acc: {val_acc}%", end="\n\n")
    
    if val_acc > best_score:
        best_score = val_acc
        best_grid = g

print("Best accuracy: ", best_score, "%")
print("Best grid: ", best_grid)
# Out:
# {'alpha': 0.05, 'fit_prior': True}
# Train acc: 99.32228156807416% 	 Val acc: 88.10369586576978%
#
# {'alpha': 0.05, 'fit_prior': False}
# Train acc: 99.32228156807416% 	 Val acc: 88.1943919582798%
#
# {'alpha': 0.1, 'fit_prior': True}
# Train acc: 99.06782223118009% 	 Val acc: 88.41357418184566%
#
# {'alpha': 0.1, 'fit_prior': False}
# Train acc: 99.06782223118009% 	 Val acc: 88.49671226664651%
#
# {'alpha': 0.5, 'fit_prior': True}
# Train acc: 97.54484530887837% 	 Val acc: 88.85571763283198%
#
# {'alpha': 0.5, 'fit_prior': False}
# Train acc: 97.54484530887837% 	 Val acc: 88.94263472148741%
#
# {'alpha': 1, 'fit_prior': True}
# Train acc: 96.1226443615842% 	 Val acc: 88.8746126521049%
#
# {'alpha': 1, 'fit_prior': False}
# Train acc: 96.1226443615842% 	 Val acc: 88.98042476003324%
#
# {'alpha': 3, 'fit_prior': True}
# Train acc: 93.28328126574624% 	 Val acc: 88.51560728591943%
#
# {'alpha': 3, 'fit_prior': False}
# Train acc: 93.28076186637105% 	 Val acc: 88.60252437457487%
#
# {'alpha': 5, 'fit_prior': True}
# Train acc: 91.92784440189459% 	 Val acc: 88.11881188118812%
#
# {'alpha': 5, 'fit_prior': False}
# Train acc: 91.9253250025194% 	 Val acc: 88.20572896984355%
#
# {'alpha': 10, 'fit_prior': True}
# Train acc: 90.36077799052707% 	 Val acc: 87.61620436852846%
#
# {'alpha': 10, 'fit_prior': False}
# Train acc: 90.35573919177668% 	 Val acc: 87.70690046103847%
#
# {'alpha': 15, 'fit_prior': True}
# Train acc: 89.57724478484329% 	 Val acc: 87.23830398307007%
#
# {'alpha': 15, 'fit_prior': False}
# Train acc: 89.57220598609291% 	 Val acc: 87.33277907943466%
#
# Best accuracy:  88.98042476003324 %
# Best grid:  {'alpha': 1, 'fit_prior': False}

# %%
sentiment_nb = MultinomialNB(alpha=0.5, class_prior=None, fit_prior=True)
X_train_val_count_sparse_matrix = count_vect.transform(X)
sentiment_nb.fit(X_train_val_count_sparse_matrix, y)
# Out:
# MultinomialNB(alpha=0.5)

# %%
sentiments = pd.read_csv("test.csv")
sentiments.dropna(inplace=True)

X_test = sentiments["Text"]

X_test_val_count_sparse_matrix = count_vect.transform(X_test)
predictions = sentiment_nb.predict(X_test_val_count_sparse_matrix)
# print(predictions)
# Out:
# [ True  True False ...  True False False]

# %%
# print(sentiments['DocumentId'].tolist())
# Out:
# [1450521, 889575, 1168201, 81808, 188577, 1454424, 2007623, 1017748, 677156, 497475, 1402401, 473428, 2173302, 302989, 1072379, 232322, 935581, 1461194, 434002, 418987, 1733540, 2381377, 3121, 656395, 1973120, 2301012, 2264073, 2184878, 1517809, 720112, 1127436, 799134, 1063138, 2368037, 304197, 94249, 401787, 377053, 2044148, 440577, 1687845, 1908227, 253239, 1622830, 949555, 2219658, 
1243368, 1725536, 2379254, 2220826, 2349997, 1080475, 1143606, 23169, 1703408, 292822, 1105079, 1343325, 2075591, 1625484, 1646388, 1185765, 491645, 298577, 1694589, 479118, 210565, 1306664, 2231388, 346907, 2310177, 2364938, 1149971, 769525, 92674, 976430, 332095, 2043100, 275503, 574498, 295224, 799465, 607466, 1129471, 225529, 2317088, 1855134, 636864, 386125, 1376106, 755839, 1205153, 1714532, 1744770, 1596346, 92174, 112986, 182970, 2245655, 2360042, 1327350, 710395, 2470542, 247441, 2292814, 1721508, 1988945, 791013, 1522521, 615827, 791194, 2441522, 336195, 1171394, 2154563, 1169332, 1095641, 2497005, 498171, 1224812, 2482175, 2314312, 1641046, 487983, 1454765, 280896, 274692, 2004533, 1612376, 2249624, 700059, 1207171, 2140243, 995263, 2348404, 1427011, 2047740, 1669192, 596357, 1147346, 1043625, 1753909, 168249, 1839093, 1653763, 1014078, 641878, 2449324, 846156, 2048390, 1834311, 890746, 2211060, 138355, 66 ...

# %%
import csv
file = open('submission.csv', 'w+', newline ='')

pred = []
ids = sentiments['DocumentId'].tolist()
header = ['DocumentId', 'IsPositive']
for i in range(len(predictions)):
    pred.append({'DocumentId': str(ids[i]),
                'IsPositive' : str(predictions[i])})
# print(pred)
with file:
    writer = csv.DictWriter(file, fieldnames = header)
    header = ['DocumentId', 'IsPositive']
    writer.writeheader()
    writer.writerows(pred)
# Out:
# [{'DocumentId': '1450521', 'IsPositive': 'True'}, {'DocumentId': '889575', 'IsPositive': 'True'}, {'DocumentId': '1168201', 'IsPositive': 'False'}, {'DocumentId': '81808', 'IsPositive': 'False'}, {'DocumentId': '188577', 'IsPositive': 'True'}, {'DocumentId': '1454424', 'IsPositive': 'True'}, {'DocumentId': '2007623', 'IsPositive': 'True'}, {'DocumentId': '1017748', 'IsPositive': 'False'}, {'DocumentId': '677156', 'IsPositive': 'False'}, {'DocumentId': '497475', 'IsPositive': 'False'}, {'DocumentId': '1402401', 'IsPositive': 'False'}, {'DocumentId': '473428', 'IsPositive': 'False'}, {'DocumentId': '2173302', 'IsPositive': 'True'}, {'DocumentId': '302989', 'IsPositive': 'False'}, {'DocumentId': '1072379', 'IsPositive': 'True'}, {'DocumentId': '232322', 'IsPositive': 'False'}, {'DocumentId': '935581', 'IsPositive': 'False'}, {'DocumentId': '1461194', 'IsPositive': 'True'}, {'DocumentId': '434002', 'IsPositive': 'True'}, {'DocumentId': '418987', 'IsPositive': 'False'}, {'DocumentId': '1733540', 'IsPositive': 'True'}, {'DocumentId': '2381377', 'IsPositive': 'False'}, {'DocumentId': '3121', 'IsPositive': 'False'}, {'DocumentId': '656395', 'IsPositive': 'True'}, {'DocumentId': '1973120', 'IsPositive': 'True'}, {'DocumentId': '2301012', 'IsPositive': 'False'}, {'DocumentId': '2264073', 'IsPositive': 'False'}, {'DocumentId': '2184878', 'IsPositive': 'True'}, {'DocumentId': '1517809', 'IsPositive': 'False'}, {'DocumentId': '720112', 'IsPositive': 'True'}, {'DocumentId': '1127436', 'IsPositive': 'True'}, {'DocumentId': '799134', 'IsPositive': 'False'}, {'DocumentId': '1063138', 'IsPositive': 'False'}, {'DocumentId': '2368037', 'IsPositive': 'False'}, {'DocumentId': '304197', 'IsPositive': 'True'}, {'DocumentId': '94249', 'IsPositive': 'False'}, {'DocumentId': '401787', 'IsPositive': 'False'}, {'DocumentId': '377053', 'IsPositive': 'False'}, {'DocumentId': '2044148', 'IsPositive': 'False'}, {'DocumentId': '440577', 'IsPositive': 'False'}, {'DocumentId': '1687845', 'IsPositive': 'False'}, {'DocumentId': '1908227', 'IsPositive': 'False'}, {'DocumentId': '253239', 'IsPositive': 'True'}, {'DocumentId': '1622830', 'IsPositive': 'False'}, {'DocumentId': '949555', 'IsPositive': 'False'}, {'DocumentId': '2219658', 'IsPositive': 'False'}, {'DocumentId': '2107788', 'IsPositive': 'True'}, {'DocumentId': '567522', 'IsPositive': 'True'}, {'DocumentId': '758259', 'IsPositive': 'False'}, {'DocumentId': '2322856', 'IsPositive': 'False'}, {'DocumentId': '2379505', 'IsPositive': 'False'}, {'DocumentId': '612916', 'IsPositive': 'True'}, {'DocumentId': '1583847', 'IsPositive': 'True'}, {'DocumentId': '2273183', 'IsPositive': 'False'}, {'DocumentId': '1649094', 'IsPositive': 'False'}, {'DocumentId': '2323193', 'IsPositive': 'False'}, {'DocumentId': '2099359', 'IsPositive': 'True'}, {'DocumentId': '2358415', 'IsPositive': 'True'}, {'DocumentId': '922135', 'IsPositive': 'False'}, {'DocumentId': '525222', 'IsPositive': 'False'}, {'DocumentId': '1537300', 'IsPositive': 'False'}, {'DocumentId': '1134961', 'IsPositive': 'True'}, {'DocumentId': '2186562', 'IsPositive': 'True'}, {'DocumentId': '1319729', 'IsPositive': 'False'}, {'DocumentId': '1447299', 'IsPositive': 'True'}, {'DocumentId': '449815', 'IsPositive': 'False'}, {'DocumentId': '2098860', 'IsPositive': 'True'}, {'DocumentId': '1776689', 'IsPositive': 'True'}, {'DocumentId': '2260691', 'IsPositive': 'True'}, {'DocumentId': '634823', 'IsPositive': 'False'}, {'DocumentId': '1703306', 'IsPositive': 'False'}, {'DocumentId': '1681282', 'IsPositive': 'False'}, {'DocumentId': '610233', 'IsPositive': 'False'}, {'DocumentId': '1306256', 'IsPositive': 'True'}, {'DocumentId': '565692', 'IsPositive': 'True'}, {'DocumentId': '626879', 'IsPositive': 'True'}, {'DocumentId': '1633371', 'IsPositive': 'False'}, {'DocumentId': '1939088', 'IsPositive': 'True'}, {'DocumentId': '1802835', 'IsPositive': 'True'}, {'DocumentId': '1346194', 'IsPositive': 'False'}, {'DocumentId': '1325774', 'IsPositive': 'True'}, {'DocumentId': '9504 ...
